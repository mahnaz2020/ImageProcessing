# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
img = cv2.imread(r'D:\AnacondaProject\mm1.PNG')
plt.imshow(img)
plt.show()
plt.close()

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
img = cv2.imread(r'D:\AnacondaProject\mm1.PNG')
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img2)
plt.show()
plt.close()

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
img = cv2.imread(r'D:\AnacondaProject\mm1.PNG')
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img2)
plt.show()
plt.close()

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
img = cv2.imread(r'D:\AnacondaProject\mm1.PNG')
img2 = cv2.line(img, (0, 0), (250, 250), (0, 255, 0), 11)
plt.imshow(img2)
plt.show()
plt.close()

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
img = cv2.imread(r'D:\AnacondaProject\mm1.PNG')
img2 = cv2.circle(img, (300,100), 40, (255,0,0), 10)
plt.imshow(img2)
plt.show()
plt.close()
